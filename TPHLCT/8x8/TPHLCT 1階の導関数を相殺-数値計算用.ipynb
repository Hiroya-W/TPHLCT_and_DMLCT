# %% [markdown]
# # TPHLCT 1階の導関数を相殺する

# %%
import numpy as np
import scipy.misc
from scipy.fftpack import dct, idct
import sys
from PIL import Image
import matplotlib
import matplotlib.pyplot as plt
import random
from tqdm._tqdm_notebook import tqdm_notebook
from scipy.fftpack import dct, idct
import seaborn as sns
from skimage.metrics import structural_similarity as ssim
import pandas as pd

# %matplotlib inline


class ImageLoader:
    def __init__(self, FILE_PATH):
        self.img = np.array(Image.open(FILE_PATH))
        # 行数
        self.row_blocks_count = self.img.shape[0] // 8
        # 列数
        self.col_blocks_count = self.img.shape[1] // 8

    def get_points(self, POINT):
        Row = random.randint(0, len(self.img) - POINT - 1)
        Col = random.randint(0, len(self.img) - 1)
        return self.img[Row : Row + POINT, Col]

    def get_block(self, col, row):
        return self.img[col * 8 : (col + 1) * 8, row * 8 : (row + 1) * 8]


# plt.rcParams['font.family'] ='sans-serif'#使用するフォント
# plt.rcParams["font.sans-serif"] = "Source Han Sans"
plt.rcParams["font.family"] = "Source Han Sans JP"  # 使用するフォント
plt.rcParams["xtick.direction"] = "in"  # x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["ytick.direction"] = "in"  # y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams["xtick.major.width"] = 1.0  # x軸主目盛り線の線幅
plt.rcParams["ytick.major.width"] = 1.0  # y軸主目盛り線の線幅
plt.rcParams["font.size"] = 12  # フォントの大きさ
plt.rcParams["axes.linewidth"] = 1.0  # 軸の線幅edge linewidth。囲みの太さ
matplotlib.font_manager._rebuild()

# 画像の用意

MONO_DIR_PATH = "../../Mono/"
AIRPLANE = ImageLoader(MONO_DIR_PATH + "airplane512.bmp")
BARBARA = ImageLoader(MONO_DIR_PATH + "barbara512.bmp")
BOAT = ImageLoader(MONO_DIR_PATH + "boat512.bmp")
GOLDHILL = ImageLoader(MONO_DIR_PATH + "goldhill512.bmp")
LENNA = ImageLoader(MONO_DIR_PATH + "lenna512.bmp")
MANDRILL = ImageLoader(MONO_DIR_PATH + "mandrill512.bmp")
MILKDROP = ImageLoader(MONO_DIR_PATH + "milkdrop512.bmp")
SAILBOAT = ImageLoader(MONO_DIR_PATH + "sailboat512.bmp")

N = 8

# %% [markdown]
# # DCT

# %% [markdown]
# ## 基底関数

# %% [markdown]
# $$
# \phi_k[i] = \begin{cases}
# \cfrac{1}{\sqrt{N}}  \quad \quad \quad (k=0) \\
# \sqrt{\cfrac{2}{N}} \cos \left({\cfrac{\pi}{2N}(2i+1)k}\right) \quad  (k=1,2,...,N-1)
# \end{cases}
# $$

# %%
class DCT:
    def __init__(self, N):
        self.N = N  # データ数
        # 1次元DCTの基底ベクトルの生成
        self.phi_1d = np.array([self.phi(i) for i in range(self.N)])
        # 2次元DCTの基底ベクトルの格納
        self.phi_2d = np.zeros((N, N))

    def phi(self, k):
        """ 離散コサイン変換(DCT)の基底関数 """
        # DCT-II
        if k == 0:
            return np.ones(self.N) / np.sqrt(self.N)
        else:
            return np.sqrt(2.0 / self.N) * np.cos(
                (k * np.pi / (2 * self.N)) * (np.arange(self.N) * 2 + 1)
            )

    def dct(self, data):
        """ 1次元離散コサイン変換を行う """
        return self.phi_1d.dot(data)

    def idct(self, c):
        """ 1次元離散コサイン逆変換を行う """
        return np.sum(self.phi_1d.T * c, axis=1)

    def get_dct2_phi(self, y, x):
        """ 2次元離散コサイン変換の基底を返す """
        phi_x, phi_y = np.meshgrid(self.phi_1d[x], self.phi_1d[y])
        return phi_x * phi_y

    def get_dct2(self, y, x, data):
        """ i,jの2次元DCT係数を返す """
        phi_2d_phi = np.zeros((self.N, self.N))
        phi_2d_phi = self.get_dct2_phi(y, x)
        return np.sum(np.sum(phi_2d_phi * data))

    def dct2(self, data):
        """ 2次元離散コサイン変換を行う """
        for y in range(self.N):
            for x in range(self.N):
                self.phi_2d[y, x] = self.get_dct2(y, x, data)

        return self.phi_2d

    def idct2(self, c):
        """ 2次元離散コサイン逆変換を行う """
        idct2_data = np.zeros((self.N, self.N))
        phi_2d_phi = np.zeros((self.N, self.N))
        for y in range(self.N):
            for x in range(self.N):
                phi_2d_phi = self.get_dct2_phi(y, x)
                idct2_data += c[y,x] * phi_2d_phi

        return idct2_data

# %% [markdown]
# # 係数の計算

# %% [markdown]
# $\alpha_k, \beta_k$を計算する。
# 1階導関数を相殺するような予測関数は
# $$
# u(x)=-\frac{f_x(0)}{2}(1-x^2)+\frac{f_x(1)}{2}x^2
# $$
# で与えられる。
#
# そのとき、
# $$\alpha_k = -\sqrt{\frac{2}{N}}\sum_{\ell=0}^{N-1}\frac{(1-x_\ell)^2}{2}\cos(\pi k x_\ell)$$
#
# $$\beta_k = \sqrt{\frac{2}{N}}\sum_{\ell=0}^{N-1}\frac{x_\ell^2}{2}\cos(\pi k x_\ell)$$

# %%
sampling_x = (0.5 + np.arange(N)) / N
u_1 = (1 - sampling_x) ** 2 / 2
u_2 = (sampling_x) ** 2 / 2
plt.plot(u_1, label="u_1")
plt.plot(u_2, label="u_2")
plt.legend()

# %%
alpha = -scipy.fftpack.dct(u_1,norm="ortho")
alpha
# Out:
# array([-0.4695631 , -0.40264519, -0.09857256, -0.04209093, -0.02209709,
#        -0.01255643, -0.00700534, -0.0031689 ])

# %%
beta = scipy.fftpack.dct(u_2,norm="ortho") 
beta
# Out:
# array([ 0.4695631 , -0.40264519,  0.09857256, -0.04209093,  0.02209709,
#        -0.01255643,  0.00700534, -0.0031689 ])

# %% [markdown]
# # DCTして残差を計算

# %% [markdown]
# $
# V_k = F_k - U_k\\
# V_k = F_k -\alpha f_x(0) -\beta f_x(1)\\
# f_x(0) \simeq \frac{F_0}{\sqrt{N}}-\frac{F_0^L}{\sqrt{N}}\\
# f_x(1) \simeq \frac{F_0^R}{\sqrt{N}}-\frac{F_0}{\sqrt{N}}\\
# V_k = F_k - \frac{\alpha}{\sqrt{N}}(F_0^R-F_0)-\frac{\beta_k}{\sqrt{N}}(F_0-F_0^L)
# $

# %% [markdown]
# ## DCT

# %% [markdown]
# 2次元入力信号を垂直方向の一次元信号が水平方向に並列に並んでいるものとみなし、各列において8画素単位の1次元DCTを適用する

# %%
IMG = SAILBOAT

# %%
Fk = np.zeros(IMG.img.shape)

# %% [markdown]
# ### 縦方向

# %%
for row in range(IMG.img.shape[0] // 8):
    for col in range(IMG.img.shape[1]):
        eight_points = IMG.img[8 * row : 8 * (row + 1), col]
        c = scipy.fftpack.dct(eight_points,norm="ortho")
        Fk[8 * row : 8 * (row + 1), col] = c

# %% [markdown]
# ### 縦方向の残差

# %%
for row in range(Fk.shape[0] // 8):
    for col in range(Fk.shape[1]):
        F = Fk[8 * row : 8 * (row + 1), col]

        F_0_r = 0
        if row is not Fk.shape[0] // 8 - 1:
            F_0_r = Fk[8 * (row + 1), col]

        F_0_l = 0
        if row is not 0:
            F_0_l = Fk[8 * (row - 1), col]

        # 残差
        F_0 = F[0]
        F = F - alpha * (F_0_r - F_0) / np.sqrt(N) - beta * (F_0 - F_0_l) / np.sqrt(N)
        # F_0は残す
        F[0] = F_0
        # F_0 V_1 V_2 V_3 V_4 V_5 V_6 V_7
        Fk[8 * row : 8 * (row + 1), col] = F

# %% [markdown]
# ### 横方向

# %%
for row in range(Fk.shape[0]):
    for col in range(Fk.shape[1] // 8):
        eight_points = Fk[row, 8 * col : 8 * (col + 1)]
        c = scipy.fftpack.dct(eight_points,norm="ortho")
        Fk[row, 8 * col : 8 * (col + 1)] = c

# %% [markdown]
# ### 横方向の残差

# %%
for row in range(Fk.shape[0]):
    for col in range(Fk.shape[1] // 8):
        F = Fk[row, 8 * col : 8 * (col + 1)]

        F_0_r = 0
        if col is not Fk.shape[1] // 8 - 1:
            F_0_r = Fk[row, 8 * (col + 1)]

        F_0_l = 0
        if col is not 0:
            F_0_l = Fk[row, 8 * (col - 1)]

        # 残差
        F_0 = F[0]
        F = F - alpha * (F_0_r - F_0) / np.sqrt(N) - beta * (F_0 - F_0_l) / np.sqrt(N)
        # F_0は残す
        F[0] = F_0
        # F_0 V_1 V_2 V_3 V_4 V_5 V_6 V_7
        Fk[row, 8 * col : 8 * (col + 1)] = F

# %% [markdown]
# # 係数の確保

# %%
Fk_Ori = np.copy(Fk)

# %% [markdown]
# ## 低域3成分 (0,1)(1,0)(1,1)の絶対値の和

# %%
low_3_value = 0
others_value = 0

# %%
for row in range(Fk.shape[0] // 8):
    for col in range(Fk.shape[1] // 8):
        block = Fk[row * 8 : (row + 1) * 8, col * 8 : (col + 1) * 8]
        low_3_value += np.abs(block[0, 1]) + np.abs(block[1, 0]) + np.abs(block[1, 1])
        others_value += (
            np.sum(np.sum(np.abs(block)))
            - np.abs(block[0, 0])
            - np.abs(block[0, 1])
            - np.abs(block[1, 0])
            - np.abs(block[1, 1])
        )

# %%
low_3_value
# Out:
# 482390.59586799867

# %%
others_value
# Out:
# 1912498.6477205514

# %%
# np.savetxt('lena_tphlct.csv', Fk, delimiter=',')

# %%
plt.imshow(Fk)

# %% [markdown]
# # 逆変換

# %% [markdown]
# $
# F_k = V_k + \frac{\alpha}{\sqrt{N}}(F_0^R-F_0)+\frac{\beta_k}{\sqrt{N}}(F_0-F_0^L)
# $

# %%
# recover = np.zeros(IMG.img.shape).astype("uint8")
recover = np.zeros(IMG.img.shape)

# %% [markdown]
# ## 横方向

# %%
for row in range(Fk.shape[0]):
    for col in range(Fk.shape[1] // 8):
        F = Fk[row, 8 * col : 8 * col + 8]

        F_0_r = 0
        if col is not Fk.shape[1] // 8 - 1:
            F_0_r = Fk[row, 8 * (col + 1)]

        F_0_l = 0
        if col is not 0:
            F_0_l = Fk[row, 8 * (col - 1)]

        # 残差
        F_0 = F[0]
        F = F + alpha * (F_0_r - F_0) / np.sqrt(N) + beta * (F_0 - F_0_l) / np.sqrt(N)
        # F_0は残す
        F[0] = F_0
        # F_0 V_1 V_2 V_3 V_4 V_5 V_6 V_7
        Fk[row, 8 * col : 8 * col + 8] = F

# %%
for row in range(Fk.shape[0]):
    for col in range(Fk.shape[1] // 8):
        F = Fk[row, 8 * col : 8 * col + 8]
        data = scipy.fftpack.idct(F,norm="ortho")
        # Fkに代入した後、縦方向に対して処理
        Fk[row, 8 * col : 8 * col + 8] = data
        # 復元画像
#         recover[row, 8 * col : 8 * col + 8] = data

# %% [markdown]
# ## 縦方向

# %%
for row in range(Fk.shape[0] // 8):
    for col in range(Fk.shape[1]):
        F = Fk[8 * row : 8 * row + 8, col]

        F_0_r = 0
        if row is not Fk.shape[0] // 8 - 1:
            F_0_r = Fk[8 * (row + 1), col]

        F_0_l = 0
        if row is not 0:
            F_0_l = Fk[8 * (row - 1), col]

        # 残差
        F_0 = F[0]
        F = F + alpha * (F_0_r - F_0) / np.sqrt(N) + beta * (F_0 - F_0_l) / np.sqrt(N)
        # F_0は残す
        F[0] = F_0
        # F_0 F_1 F_2 F_3 F_4 F_5 F_6 F_7
        Fk[8 * row : 8 * row + 8, col] = F

# %%
for row in range(Fk.shape[0] // 8):
    for col in range(Fk.shape[1]):
        F = Fk[8 * row : 8 * (row + 1), col]
        data = scipy.fftpack.idct(F,norm="ortho")
        # 復元画像
        recover[8 * row : 8 * (row + 1), col] = data
        # FKに代入した後、横方向に対して処理
#         Fk[8 * row : 8 * (row + 1), col] = data

# %%
plt.imshow(np.round(recover),cmap="gray")

# %%
plt.imshow(IMG.img, cmap="gray")

# %%
recover[0,0:10]
# Out:
# array([30., 13., 15., 18., 19., 15., 15., 12., 15., 18.])

# %%
IMG.img[0,0:10]
# Out:
# array([30, 13, 15, 18, 19, 15, 15, 12, 15, 18], dtype=uint8)

# %% [markdown]
# ちゃんと復元できた

# %% [markdown]
# # 量子化テーブル

# %%
Q50_Luminance = np.array(
    [
        [16, 11, 10, 16, 24, 40, 51, 61],
        [12, 12, 14, 19, 26, 58, 60, 55],
        [14, 13, 16, 24, 40, 57, 69, 56],
        [14, 17, 22, 29, 51, 87, 80, 62],
        [18, 22, 37, 56, 68, 109, 103, 77],
        [24, 35, 55, 64, 81, 104, 113, 92],
        [49, 64, 78, 87, 103, 121, 120, 101],
        [72, 92, 95, 98, 112, 100, 103, 99],
    ]
)

# %% [markdown]
# $$
# S = (Q < 50)?\frac{5000}{Q}:200-2Q\\
# Q_s[i] = \left[\frac{S\times Q_b[i]+50}{100}\right]
# $$

# %%
for i in tqdm_notebook(np.arange(1,10000,1)):
    Q = 2.5 + i / 100
    Q_Luminance = np.copy(Q50_Luminance)
    if Q < 50:
        Q_Luminance = Q_Luminance * 50 / Q
        Q_Luminance = np.where(Q_Luminance > 255, 255, Q_Luminance)
    else:
        Q_Luminance = (100 - Q) * Q50_Luminance / 50
        Q_Luminance = np.where(Q_Luminance < 1, 1, Q_Luminance)

    Fk = np.copy(Fk_Ori)
    Q_Fk = np.zeros(Fk.shape)
    for row in range(IMG.img.shape[0] // 8):
        for col in range(IMG.img.shape[1] // 8):
            block = Fk[row * 8 : (row + 1) * 8, col * 8 : (col + 1) * 8]
            # 量子化
            block = np.round(block / Q_Luminance)
            # 逆量子化
            block = block * Q_Luminance
            Q_Fk[row * 8 : (row + 1) * 8, col * 8 : (col + 1) * 8] = block
    
    qfk = pd.Series(Q_Fk.flatten())
    pro = qfk.value_counts() / qfk.value_counts().sum()

    S = 0
    for pi in pro:
        S -= pi * np.log2(pi)
    
#     print("S=",S)
    bpp = np.arange(0.2,0.8,0.05)
    for i in bpp:
        if np.abs(i - S) < 0.002:
            Fk = np.copy(Q_Fk)
            Q_recover = np.zeros(Q_Fk.shape)
            # 横方向
            for row in range(Fk.shape[0]):
                for col in range(Fk.shape[1] // 8):
                    F = Fk[row, 8 * col : 8 * col + 8]

                    F_0_r = 0
                    if col is not Fk.shape[1] // 8 - 1:
                        F_0_r = Fk[row, 8 * (col + 1)]

                    F_0_l = 0
                    if col is not 0:
                        F_0_l = Fk[row, 8 * (col - 1)]

                    # 残差
                    F_0 = F[0]
                    F = F + alpha * (F_0_r - F_0) / np.sqrt(N) + beta * (F_0 - F_0_l) / np.sqrt(N)
                    # F_0は残す
                    F[0] = F_0
                    # F_0 V_1 V_2 V_3 V_4 V_5 V_6 V_7
                    Fk[row, 8 * col : 8 * col + 8] = F

            for row in range(Fk.shape[0]):
                for col in range(Fk.shape[1] // 8):
                    F = Fk[row, 8 * col : 8 * col + 8]
                    data = scipy.fftpack.idct(F,norm="ortho")
                    # Fkに代入した後、縦方向に対して処理
                    Fk[row, 8 * col : 8 * col + 8] = data
                    # 復元画像
            #         recover[row, 8 * col : 8 * col + 8] = data

            # 縦方向
            for row in range(Fk.shape[0] // 8):
                for col in range(Fk.shape[1]):
                    F = Fk[8 * row : 8 * row + 8, col]

                    F_0_r = 0
                    if row is not Fk.shape[0] // 8 - 1:
                        F_0_r = Fk[8 * (row + 1), col]

                    F_0_l = 0
                    if row is not 0:
                        F_0_l = Fk[8 * (row - 1), col]

                    # 残差
                    F_0 = F[0]
                    F = F + alpha * (F_0_r - F_0) / np.sqrt(N) + beta * (F_0 - F_0_l) / np.sqrt(N)
                    # F_0は残す
                    F[0] = F_0
                    # F_0 F_1 F_2 F_3 F_4 F_5 F_6 F_7
                    Fk[8 * row : 8 * row + 8, col] = F

            for row in range(Fk.shape[0] // 8):
                for col in range(Fk.shape[1]):
                    F = Fk[8 * row : 8 * (row + 1), col]
                    data = scipy.fftpack.idct(F,norm="ortho")
                    # 復元画像
                    Q_recover[8 * row : 8 * (row + 1), col] = data
                    # FKに代入した後、横方向に対して処理
            #         Fk[8 * row : 8 * (row + 1), col] = data
            Q_recover = np.round(Q_recover)

            MSE = np.sum(np.sum(np.power((IMG.img - Q_recover),2)))/(Q_recover.shape[0] * Q_recover.shape[1])
            PSNR = 10 * np.log10(255 * 255 / MSE)
            MSSIM = ssim(IMG.img,Q_recover.astype(IMG.img.dtype),gaussian_weights=True,sigma=1.5,K1=0.01,K2=0.03)
            w_e = 0
            e_e = 0
            n_e = 0
            s_e = 0
            nw_e = 0
            ne_e = 0
            sw_e = 0
            se_e = 0
            for row in range(Q_recover.shape[0] // 8):
                for col in range(Q_recover.shape[1] // 8):
                    f_block = Q_recover[row * 8 : (row + 1) * 8, col * 8 : (col + 1) * 8]
                    # w
                    if col == 0:
                        w_block = np.fliplr(f_block)
                    else:
                        w_block = Q_recover[row * 8 : (row + 1) * 8, (col - 1) * 8 : col * 8]
                    # e
                    if col == Q_recover.shape[1] // 8 - 1:
                        e_block = np.fliplr(f_block)
                    else:
                        e_block = Q_recover[row * 8 : (row + 1) * 8, (col + 1) * 8 : (col + 2) * 8]
                    # n
                    if row == 0:
                        n_block = np.flipud(f_block)
                    else:
                        n_block = Q_recover[(row - 1) * 8 : row * 8, col * 8 : (col + 1) * 8]
                    # s
                    if row == Q_recover.shape[0] // 8 - 1:
                        s_block = np.flipud(f_block)
                    else:
                        s_block = Q_recover[(row + 1) * 8 : (row + 2) * 8, col * 8 : (col + 1) * 8]

                    w_d1 = f_block[:, 0] - w_block[:, 7]
                    e_d1 = f_block[:, 7] - e_block[:, 0]
                    n_d1 = f_block[0, :] - n_block[7, :]
                    s_d1 = f_block[7, :] - s_block[0, :]

                    w_d2 = (w_block[:, 7] - w_block[:, 6] + f_block[:, 1] - f_block[:, 0]) / 2
                    e_d2 = (e_block[:, 1] - e_block[:, 0] + f_block[:, 7] - f_block[:, 6]) / 2
                    n_d2 = (n_block[7, :] - n_block[6, :] + f_block[1, :] - f_block[0, :]) / 2
                    s_d2 = (s_block[1, :] - s_block[0, :] + f_block[7, :] - f_block[6, :]) / 2

                    w_e += np.sum((w_d1 - w_d2) ** 2 )
                    e_e += np.sum((e_d1 - e_d2) ** 2 )
                    n_e += np.sum((n_d1 - n_d2) ** 2)
                    s_e += np.sum((s_d1 - s_d2) ** 2)

                    # nw
                    if row == 0 or col == 0:
                        nw_block = np.flipud(np.fliplr(f_block))
                    else:
                        nw_block = Q_recover[(row - 1) * 8 : row * 8, (col - 1) * 8 : col * 8]
                    # ne
                    if row == 0 or col == Q_recover.shape[1] // 8 - 1:
                        ne_block = np.flipud(np.fliplr(f_block))
                    else:
                        ne_block = Q_recover[(row-1) * 8 : row * 8, (col + 1) * 8 : (col + 2) * 8]
                    # sw
                    if row == Q_recover.shape[0] // 8 -1 or col == 0:
                        sw_block = np.flipud(np.fliplr(f_block))
                    else:
                        sw_block = Q_recover[row * 8 : (row+1) * 8, (col-1) * 8 : col * 8]
                    # se
                    if  row == Q_recover.shape[0]//8-1 or col == Q_recover.shape[0] // 8 -1:
                        se_block = np.flipud(np.fliplr(f_block))
                    else:
                        se_block = Q_recover[(row + 1) * 8 : (row + 2) * 8, (col+1) * 8 : (col + 2) * 8]

                    nw_g1 = f_block[0, 0] - nw_block[7, 7]
                    ne_g1 = f_block[0, 7] - ne_block[7, 0]
                    sw_g1 = f_block[7, 0] - sw_block[0, 7]
                    se_g1 = f_block[7, 7] - se_block[0, 0]

                    nw_g2 = (nw_block[7,7] - nw_block[6,6] + f_block[1,1] - f_block[0,0])/2
                    ne_g2 = (ne_block[7,0] - ne_block[6,1] + f_block[1,6] - f_block[0,7])/2
                    sw_g2 = (sw_block[0,7] - nw_block[1,6] + f_block[6,1] - f_block[7,0])/2
                    se_g2 = (nw_block[0,0] - nw_block[1,1] + f_block
# S= 0.7519670735056503
# 12.46 28.436636806012473 0.7800783164194093 14195.444946289062 6221.448425292969
# S= 0.7988366927380974
# 13.58 28.723990501717044 0.7892117691869467 13667.502807617188 6107.2900390625
# S= 0.7980747269849426
# 13.59 28.72558932455987 0.7891196078391378 13663.634887695312 6109.675598144531
# S= 0.7990226107357169
# 13.6 28.728283409987483 0.7894858461878442 13653.464477539062 6116.839904785156
# S= 0.8003483777509338
# 13.61 28.730785525476236 0.7897620496930564 13637.963134765625 6100.945861816406
# S= 0.7996721315794277
# 13.62 28.73429829700767 0.7898557694247271 13617.695556640625 6084.570983886719
# S= 0.8002302594009492
# 13.63 28.73570686758278 0.7900582764543767 13590.409912109375 6079.9130859375
# S= 0.8006311464660937
# 13.64 28.73902046581881 0.7901094233966092 13574.002685546875 6067.183288574219
# S= 0.8005993410683045
# 13.65 28.74125667752005 0.7899979979824108 13569.73876953125 6066.604797363281
# S= 0.8012366370031268
# 13.66 28.744208729994718 0.7902655071305862 13568.015502929688 6069.835754394531
# S= 0.8011816332149306
# 13.67 28.746816070510913 0.7901578301870388 13572.333251953125 6072.746520996094
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-fb702c73458b> in <module>
#      21
#      22     qfk = pd.Series(Q_Fk.flatten())
# ---> 23     pro = qfk.value_counts() / qfk.value_counts().sum()
#      24
#      25     S = 0
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/base.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#    1390             normalize=normalize,
#    1391             bins=bins,
# -> 1392             dropna=dropna,
#    1393         )
#    1394         return result
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     762
#     763     if sort:
# --> 764         result = result.sort_values(ascending=ascending)
#     765
#     766     if normalize:
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position)
#    3176         if na_position == "last":
#    3177             n = good.sum()
# -> 3178             sortedIdx[:n] = idx[good][argsorted]
#    3179             sortedIdx[n:] = idx[bad]
#    3180         elif na_position == "first":
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4284         result = getitem(key)
#    4285         if not is_scalar(result):
# -> 4286             return promote(result)
#    4287         else:
#    4288             return result
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/indexes/numeric.py in _shallow_copy(self, values, **kwargs)
#      84         if values is not None and not self._can_hold_na:
#      85             # Ensure we are not returning an Int64Index with float data:
# ---> 86             return self._shallow_copy_with_infer(values=values, **kwargs)
#      87         return super()._shallow_copy(values=values, **kwargs)
#      88
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in _shallow_copy_with_infer(self, values, **kwargs)
#     674             except (TypeError, ValueError):
#     675                 pass
# --> 676         return Index(values, **attributes)
#     677
#     678     def _update_inplace(self, result, **kwargs):
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     445                 from .numeric import Int64Index
#     446
# --> 447                 return Int64Index(data, copy=copy, dtype=dtype, name=name)
#     448             elif is_unsigned_integer_dtype(data.dtype):
#     449                 from .numeric import UInt64Index
#
# ~/Documents/Jupyter-Notebook/.venv/lib/python3.6/site-packages/pandas/core/indexes/numeric.py in __new__(cls, data, dtype, copy, name, fastpath)
#      60         data = cls._coerce_to_ndarray(data)
#      61
# ---> 62         if issubclass(data.dtype.type, str):
#      63             cls._string_data_error(data)
#      64
#
# KeyboardInterrupt:
